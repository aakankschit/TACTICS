# %% [markdown]
# # Clean up Quinazoline Dataset
# This is a check to see if we get the same results as Pat Walters did when comparing ETS and TS.

# %%
import polars as pl

# %%
df = pl.read_parquet("/Users/aakankschitnandkeolyar/Desktop/TACTICS/data/reagents/quinazoline/niementowski.parquet")

# %%
df
# Out:
# shape: (1_000_000, 111)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Name      ┆ ShapeQuer ┆ query_001 ┆ query_002 ┆ … ┆ query_106 ┆ query_107 ┆ query_108 ┆ query_10 │
# │ ---       ┆ y         ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ 9        │
# │ str       ┆ ---       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 3888941_2 ┆ MOL001_1  ┆ 0.988     ┆ 0.835     ┆ … ┆ 0.889     ┆ 0.716     ┆ 0.687     ┆ 0.933    │
# │ 0436848_6 ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 660936    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...
