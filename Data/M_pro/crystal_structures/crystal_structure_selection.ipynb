# %% [markdown]
# # SARS-CoV-2 Crystal $M_{pro}$ Structure Analysis

# %%
import os
import glob
import requests
from Bio.PDB import PDBList, PDBParser

# %% [markdown]
# ## Functions

# %%
# Find all pdb files in a directory and return them as a list
def find_pdb_files(directory):
    """
    Finds all .pdb files in the specified directory and returns them as a list.

    Parameters:
    - directory: The path to the directory where .pdb files should be searched.

    Returns:
    - List of paths to .pdb files found in the directory.
    """
    # Use glob to find all .pdb files in the directory
    pdb_files = glob.glob(os.path.join(directory, '*.pdb'))

    # Optional: Print the list of found .pdb files
    print("Found PDB files:")
    for file in pdb_files:
        print(file)

    # Return the list of PDB files
    return pdb_files

# %%
# Function to download PDB files
PDB_BASE_URL = "https://files.rcsb.org/download/"

def download_pdbs(pdb_codes_file, output_dir):
    """
    Download PDB structures from a text file containing PDB codes.

    Parameters:
    - pdb_codes_file: Path to the text file containing PDB codes (one per line)
    - output_dir: Directory to save downloaded PDB files
    """
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Read PDB codes from the file
    with open(pdb_codes_file, 'r') as f:
        pdb_codes = [line.strip().upper() for line in f if line.strip()]

    # Download each PDB structure
    for pdb_code in pdb_codes:
        try:
            pdb_url = f"{PDB_BASE_URL}{pdb_code}.pdb"
            response = requests.get(pdb_url)
            response.raise_for_status()  # Check for request errors

            pdb_file_path = os.path.join(output_dir, f"{pdb_code}.pdb")
            with open(pdb_file_path, 'wb') as pdb_file:
                pdb_file.write(response.content)

            print(f"Successfully downloaded: {pdb_code}")
        except Exception as e:
            print(f"Failed to download {pdb_code}: {e}")

    print(f"Download complete. Files are saved in: {output_dir}")

    return pdb_codes

# %%
# Functions to get resolutions of crystal structures from pdb files
def get_pdb_resolution(pdb_code):
    """
    Fetches the resolution of a PDB structure from the downloaded file.

    Parameters:
    - pdb_code: The 4-character PDB code

    Returns:
    - Resolution (float) if available, otherwise None
    """
    # Initialize PDBList to download the structure
    pdbl = PDBList()

    # Download the PDB file (in .ent format by default)
    pdb_file = pdbl.retrieve_pdb_file(pdb_code, pdir=".", file_format="pdb")

    # Parse the downloaded PDB file
    parser = PDBParser(QUIET=True)

    try:
        structure = parser.get_structure(pdb_code, pdb_file)
        # Extract resolution from the header
        resolution = structure.header.get('resolution')
        return resolution
    except Exception as e:
        print(f"Error processing {pdb_code}: {e}")
        return None

def fetch_resolutions_from_file(pdb_codes_file):
    """
    Reads a list of PDB codes from a text file and fetches their resolutions.

    Parameters:
    - pdb_codes_file: Path to the text file containing PDB codes (one per line)

    Returns:
    - A dictionary with PDB codes as keys and their resolutions as values
    """
    resolutions = {}

    # Read PDB codes from the file
    with open(pdb_codes_file, 'r') as f:
        pdb_codes = [line.strip().upper() for line in f if line.strip()]

    # Fetch resolution for each PDB code
    for pdb_code in pdb_codes:
        resolution = get_pdb_resolution(pdb_code)
        resolutions[pdb_code] = resolution
        print(f"PDB Code: {pdb_code}, Resolution: {resolution}")

    return resolutions

# %% [markdown]
# # Scripts

# %%
# ./Moonshot_crystal_structures/7GFU.pdb
# ./Moonshot_crystal_structures/7GEN.pdb
# ./Moonshot_crystal_structures/7GF4.pdb
# ./Moonshot_crystal_structures/7GF5.pdb
# ./Moonshot_crystal_structures/7GEO.pdb
# ./Moonshot_crystal_structures/7GFT.pdb
# ./Moonshot_crystal_structures/7GDK.pdb
# ./Moonshot_crystal_structures/7GG1.pdb
# ./Moonshot_crystal_structures/7GGP.pdb
# ./Moonshot_crystal_structures/7GE9.pdb
# ./Moonshot_crystal_structures/7GFC.pdb
# ./Moonshot_crystal_structures/7GEX.pdb
# ./Moonshot_crystal_structures/7GGG.pdb
# ./Moonshot_crystal_structures/7GJW.pdb
# ./Moonshot_crystal_structures/7GJ6.pdb
# ./Moonshot_crystal_structures/7GIL.pdb
# ./Moonshot_crystal_structures/7GKS.pdb
# ./Moonshot_crystal_structures/7GHH.pdb
# ./Moonshot_crystal_structures/7GK2.pdb
# ./Moonshot_crystal_structures/7GKD.pdb
# ./Moonshot_crystal_structures/7GJB.pdb
# ./Moonshot_crystal_structures/7GI8.pdb
# ./Moonshot_crystal_structures/7GIY.pdb
# ./Moonshot_crystal_structures/7GKF.pdb
# ./Moonshot_crystal_structures/7GIN.pdb
# ./Moonshot_crystal_structures/7GJ4.pdb
# ./Moonshot_crystal_structures/7GJU.pdb
# ./Moonshot_crystal_structures/7GK0.pdb
# ./Moonshot_crystal_structures/7GHJ.pdb
# ./Moonshot_crystal_structures/7GKQ.pdb
# ./Moonshot_crystal_structures/7GEZ.pdb
# ./Moonshot_crystal_structures/7GFA.pdb
# ./Moonshot_crystal_structures/7GGE.pdb
# ./Moonshot_crystal_structures/7GFV.pdb
# ./Moonshot_crystal_structures/7GEM.pdb
# ./Moonshot_crystal_structures/7GF7.pdb
# ./Moonshot_crystal_structures/7GGR.pdb
# ./Moonshot_crystal_structures/7GG3.pdb
# ./Moonshot_crystal_structures/7GDI.pdb
# ./Moonshot_crystal_structures/7GDH.pdb
# ./Moonshot_crystal_structures/7GG2.pdb
# ./Moonshot_crystal_structures/7GGS.pdb
# ./Moonshot_crystal_structures/7GF6.pdb
# ./Moonshot_crystal_structures/7GEL.pdb
# ./Moonshot_crystal_structures/7GFW.pdb
# ./Moonshot_crystal_structures/7GGD.pdb
# ./Moonshot_crystal_structures/7GKP.pdb
# ./Moonshot_crystal_structures/7GHK.pdb
# ./Moonshot_crystal_structures/7GK1.pdb
# ./Moonshot_crystal_structures/7GJT.pdb
# ./Moonshot_crystal_structures/7GJ5.pdb
# ./Moonshot_crystal_structures/7GIO.pdb
# ./Moonshot_crystal_structures/7GKG.pdb
# ./Moonshot_crystal_structures/7GIX.pdb
# ./Moonshot_crystal_structures/7GI9.pdb
# ./Moonshot_crystal_structures/7GJC.pdb

# %%
# Get the PDB ids from the text file
with open("covid_moonshot_pdb_ids.txt", "r") as f:
    pdb_codes = [line.strip() for line in f]
